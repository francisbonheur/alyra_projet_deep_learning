# %% [markdown]
# <a href="https://colab.research.google.com/github/francisbonheur/alyra_projet_deep_learning/blob/main/notebooks/cv-violence-detection-mobilenetv2-fine-tuning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Computer vision : détection d'images violentes (fine tuning)
#
# ## Chargement modules python

# %%
# Bibliothèques principales
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import clear_output, Image as IPImage, display
import warnings
import os
from pathlib import Path
warnings.filterwarnings('ignore')

# TensorFlow et Keras
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models, optimizers, callbacks
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.preprocessing import image_dataset_from_directory
from tensorflow.keras.utils import image_dataset_from_directory

# %% [markdown]
# ## Chargement du modèle MobileNetV2 avec Keras

# %%
print("📥 Chargement du modèle MobileNetV2 avec Keras...")
print("   (Cela peut prendre quelques secondes la première fois)\n")

# Charger MobileNetV2 pré-entraîné sans le classifier (include_top=False)
base_model = MobileNetV2(
    input_shape=(224, 224, 3),
    include_top=False,  # Exclure la couche de classification ImageNet
    weights='imagenet',  # Charger les poids pré-entraînés sur ImageNet
    pooling='avg'  # Global Average Pooling à la fin
)
# Out:
# 📥 Chargement du modèle MobileNetV2 avec Keras...
#    (Cela peut prendre quelques secondes la première fois)
#
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %% [markdown]
# ## Chaergement du dataset

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("abdulmananraja/real-life-violence-situations")

data_dir = path + "/new_violence"

print("Path to dataset files:", data_dir)
# Out:
# Downloading from https://www.kaggle.com/api/v1/datasets/download/abdulmananraja/real-life-violence-situations?dataset_version_number=1...
# 100%|██████████| 225M/225M [00:03<00:00, 70.9MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/abdulmananraja/real-life-violence-situations/versions/1/new_violence

# %% [markdown]
# ## Préparation du dataset

# %%
print("🔧 Préparation des datasets...\n")

# Paramètres
BATCH_SIZE = 32
IMG_SIZE = (224, 224)
VALIDATION_SPLIT = 0.2
SEED = 42

# Créer le dataset d'entraînement avec filtrage des classes
train_ds = tf.keras.utils.image_dataset_from_directory(
    data_dir,
    validation_split=VALIDATION_SPLIT,
    subset="training",
    seed=SEED,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    label_mode='binary',
    labels='inferred'
)

# Créer le dataset de validation avec les mêmes classes
val_ds = tf.keras.utils.image_dataset_from_directory(
    data_dir,
    validation_split=VALIDATION_SPLIT,
    subset="validation",
    seed=SEED,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    label_mode='binary',
    labels='inferred'
)

# Obtenir les noms de classes (devrait être les 5 classes de fleurs)
class_names = train_ds.class_names
num_classes = len(class_names)

print(f"✅ Datasets créés !\n")
print(f"📊 Information sur les datasets :")
print(f"  - Classes        : {class_names}")
print(f"  - Nombre de classes : {num_classes}")

print(f"\n  - Train batches  : {len(train_ds)}")
print(f"  - Val batches    : {len(val_ds)}")

print(f"  - Batch size     : {BATCH_SIZE}")
print(f"  - Image size     : {IMG_SIZE}")
print(f"\n  - Train samples  : ~{len(train_ds) * BATCH_SIZE}")
print(f"  - Val samples    : ~{len(val_ds) * BATCH_SIZE}")
# Out:
# 🔧 Préparation des datasets...
#
# Found 11073 files belonging to 2 classes.
# Using 8859 files for training.
# Found 11073 files belonging to 2 classes.
# Using 2214 files for validation.
# ✅ Datasets créés !
#
# 📊 Information sur les datasets :
#   - Classes        : ['non_violence', 'violence']
#   - Nombre de classes : 2
#
#   - Train batches  : 277
#   - Val batches    : 70
#   - Batch size     : 32
#   - Image size     : (224, 224)
#
#   - Train samples  : ~8864
#   - Val samples    : ~2240

# %% [markdown]
# ## Préprocessing (normalisation et data augmentation)

# %%
print("🎨 Configuration du prétraitement et de la data augmentation...\n")

# Créer une fonction de prétraitement pour MobileNetV2
from tensorflow.keras.applications.mobilenet_v2 import preprocess_input

# Créer un modèle d'augmentation de données plus agressif
data_augmentation = keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.3),  # Rotation jusqu'à 30%
    layers.RandomZoom(0.2),
], name="data_augmentation")

# Fonction pour appliquer le prétraitement
def prepare_dataset(ds, augment=False, shuffle=True):
    # Normalisation MobileNetV2
    normalization = lambda x, y: (preprocess_input(x), y)
    ds = ds.map(normalization, num_parallel_calls=tf.data.AUTOTUNE)

    # Augmentation (seulement pour le train)
    if augment:
        augmentation = lambda x, y: (data_augmentation(x, training=True), y)
        ds = ds.map(augmentation, num_parallel_calls=tf.data.AUTOTUNE)

    # Shuffle pour le training
    if shuffle:
        ds = ds.shuffle(1000)

    # Optimisation des performances
    ds = ds.cache()  # Cache en mémoire
    ds = ds.prefetch(buffer_size=tf.data.AUTOTUNE)  # Prefetch pour accélérer

    return ds

# Appliquer le prétraitement
train_ds_prepared = prepare_dataset(train_ds, augment=True, shuffle=True)
val_ds_prepared = prepare_dataset(val_ds, augment=False, shuffle=False)
# Out:
# 🎨 Configuration du prétraitement et de la data augmentation...

# %% [markdown]
# ##  Effet de la data augmentation

# %%
# Prendre un batch d'exemples
for images, labels in train_ds.take(1):
    # Prendre la première image
    sample_image = images[0].numpy().astype("uint8")

    # Appliquer l'augmentation 9 fois
    fig, axes = plt.subplots(2, 5, figsize=(18, 8))
    axes = axes.flatten()

    # Image originale
    axes[0].imshow(sample_image)
    axes[0].set_title('Original', fontsize=12, fontweight='bold')
    axes[0].axis('off')

    # Images augmentées
    for i in range(1, 10):
        augmented = data_augmentation(tf.expand_dims(sample_image, 0), training=True)
        axes[i].imshow(augmented[0].numpy().astype("uint8"))
        axes[i].set_title(f'Augmentation {i}', fontsize=12)
        axes[i].axis('off')

    plt.suptitle('Effet de la Data Augmentation', fontsize=16, fontweight='bold', y=0.98)
    plt.tight_layout()
    plt.show()
    break

# %% [markdown]
# ## Construction du modèle Feature Extraction

# %%
# Geler le modèle de base
base_model.trainable = True

fine_tune_at = 100

for i, layer in enumerate(base_model.layers):
    if i < fine_tune_at:
        layer.trainable = False
    else:
        layer.trainable = True



print(f"✅ Modèle de base gelé")
print(f"   {len(base_model.layers)} couches non-entraînables\n")

# Architecture OPTIMALE pour ce dataset
inputs = keras.Input(shape=(224, 224, 3))
x = base_model(inputs, training=False)

# Classifier avec régularisation modérée
x = layers.Dropout(0.3)(x)  # Dropout modéré
x = layers.Dense(256, activation='relu', kernel_regularizer=keras.regularizers.l2(0.01))(x)
x = layers.Dropout(0.3)(x)
outputs = layers.Dense(1, activation='sigmoid')(x)

model_frozen = keras.Model(inputs, outputs, name='MobileNetV2_Frozen')

FINE_TUNE_LR = 1e-5  # LR très faible

# Compiler avec LR optimal
model_frozen.compile(
    optimizer=optimizers.Adam(learning_rate=FINE_TUNE_LR),  # LR standard
    loss='binary_crossentropy',
    metrics=['accuracy', 'recall']
)

model_finetuned = model_frozen

trainable = sum([tf.size(w).numpy() for w in model_finetuned.trainable_weights])
non_trainable = sum([tf.size(w).numpy() for w in model_finetuned.non_trainable_weights])

print(f"\n  - Paramètres entraînables    : {trainable:,}")
print(f"  - Paramètres non-entraînables: {non_trainable:,}")
print(f"  - Total                      : {trainable + non_trainable:,}")
# Out:
# ✅ Modèle de base gelé
#    155 couches non-entraînables
#
#
#   - Paramètres entraînables    : 2,189,633
#   - Paramètres non-entraînables: 396,544
#   - Total                      : 2,586,177

# %% [markdown]
# ## Entraînement du modèle

# %%
# Callbacks
early_stopping = callbacks.EarlyStopping(
    monitor='val_recall',
    patience=20,  # Patience raisonnable
    restore_best_weights=True,
    mode='max',
    verbose=1
)

reduce_lr = callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=4,
    min_lr=1e-7,
    verbose=1
)

checkpoint = callbacks.ModelCheckpoint(
    'best_model_frozen.keras',
    monitor='val_recall',
    save_best_only=True,
    mode='max',
    verbose=0
)

EPOCHS_FINETUNE = 50

history_frozen = model_frozen.fit(
    train_ds_prepared,
    validation_data=val_ds_prepared,
    epochs=EPOCHS_FINETUNE,
    callbacks=[early_stopping, reduce_lr, checkpoint],
    verbose=1
)

print(f"   Epochs effectués : {len(history_frozen.history['loss'])}")

best_val_recall = max(history_frozen.history['val_recall'])
best_val_accuracy = max(history_frozen.history['val_accuracy'])
best_epoch_recall = history_frozen.history['val_recall'].index(best_val_recall) + 1
best_epoch_accuracy = history_frozen.history['val_accuracy'].index(best_val_accuracy) + 1
print(f"   Meilleure val_recall : {best_val_recall*100:.2f}% (epoch {best_epoch_recall})")
print(f"   Meilleure val_accuracy : {best_val_accuracy*100:.2f}% (epoch {best_epoch_accuracy})")
# Out:
# Epoch 1/50
# 277/277 ━━━━━━━━━━━━━━━━━━━━ 54s 118ms/step - accuracy: 0.6133 - loss: 4.8958 - recall: 0.6799 - val_accuracy: 0.8026 - val_loss: 4.5145 - val_recall: 0.9664 - learning_rate: 1.0000e-05
# Epoch 2/50
# 277/277 ━━━━━━━━━━━━━━━━━━━━ 14s 50ms/step - accuracy: 0.8242 - loss: 4.4498 - recall: 0.8294 - val_accuracy: 0.8613 - val_loss: 4.2183 - val_recall: 0.9362 - learning_rate: 1.0000e-05
# Epoch 3/50
# 277/277 ━━━━━━━━━━━━━━━━━━━━ 14s 49ms/step - accuracy: 0.8742 - loss: 4.1696 - recall: 0.8761 - val_accuracy: 0.8984 - val_loss: 3.9743 - val_recall: 0.9135 - learning_rate: 1.0000e-05
# Epoch 4/50
# 277/277 ━━━━━━━━━━━━━━━━━━━━ 14s 49ms/step - accuracy: 0.9059 - loss: 3.9277 - recall: 0.9070 - val_accuracy: 0.9083 - val_loss: 3.7796 - val_recall: 0.8850 - learning_rate: 1.0000e-05
# Epoch 5/50
# 277/277 ━━━━━━━━━━━━━━━━━━━━ 14s 49ms/step - accuracy: 0.9253 - loss: 3.7024 - recall: 0.9213 - val_accuracy: 0.9178 - val_loss: 3.5953 - val_recall: 0.8799 - learning_rate: 1.0000e-05
# Epoch 6/50
# 277/277 ━━━━━━━━━━━━━━━━━━━━ 14s 49ms/step - accuracy: 0.9384 - loss: 3.4911 - recall: 0.9395 - val_accuracy: 0.9115 - val_loss: 3.4230 - val_recall: 0.8648 - learning_rate: 1.0000e-05
# Epoch 7/50
# 277/277 ━━━━━━━━━━━━━━━━━━━━ 14s 49ms/step - accuracy: 0.9550 - loss: 3.2878 - recall: 0.9548 - val_accuracy: 0.9083 - val_loss: 3.2561 - val_recall: 0.8564 - learning_rate: 1.0000e-05
# Epoch 8/50
# 277/277 ━━━━━━━━━━━━━━━━━━━━ 14s 49ms/step - accuracy: 0.9703 - loss: 3.0873 - recall: 0.9695 - val_accuracy: 0.9015 - val_loss: 3.1199 - val_recall: 0.8346 - learning_rate: 1.0000e-05
# Epoch 9/50
# 277/277 ━━━━━━━━━━━━━━━━━━━━ 14s 50ms/step - accuracy: 0.9793 - loss: 2.8956 - recall: 0.9812 - val_accuracy: 0.8957 - val_loss: 2.9650 - val_recall: 0.8220 - learning_rate: 1.0000e-05
# Epoch 10/50
# 277/277 ━━━━━━━━━━━━━━━━━━━━ 14s 50ms/step - accuracy: 0.9842 - loss: 2.7108 - recall: 0.9870 - val_accuracy: 0.8862 - val_loss: 2.8365 - val_recall: 0.8018 - learning_rate: 1.0000e-05
# Epoch 11/50
# 277/277 ━━━━━━━━━━━━━━━━━━━━ 14s 50ms/step - accuracy: 0.9921 - loss: 2.5297 - recall: 0.9918 - val_accuracy: 0.8871 - val_loss: 2.6951 - val_recall: 0.8018 - learning_rate: 1.0000e-05
# Epoch 12/50
# 277/277 ━━━━━━━━━━━━━━━━━━━━ 14s 50ms/step - accuracy: 0.9945 - loss: 2.3567 - recall: 0.9923 - val_accuracy: 0.8857 - val_loss: 2.5494 - val_recall: 0.7993 - learning_rate: 1.0000e-05
# Epoch 13/50
# 277/277 ━━━━━━━━━━━━━━━━━━━━ 14s 49ms/step - accuracy: 0.9973 - loss: 2.1857 - recall: 0.9962 - val_accuracy: 0.8993 - val_loss: 2.3612 - val_recall: 0.8254 - learning_rate: 1.0000e-05
# Epoch 14/50
# 277/277 ━━━━━━━━━━━━━━━━━━━━ 14s 50ms/step - accuracy: 0.9993 - loss: 2.0176 - recall: 0.9987 - val_accuracy: 0.8921 - val_loss: 2.2425 - val_recall: 0.8111 - learning_rate: 1.0000e-05
# Epoch 15/50
# 277/277 ━━━━━━━━━━━━━━━━━━━━ 14s 50ms/step - accuracy: 0.9998 - loss: 1.8542 - recall: 0.9999 - val_accuracy: 0.8916 - val_loss: 2.0957 - val_recall: 0.8111 - learning_rate: 1.0000e-05
# Epoch 16/50
# 277/277 ━━━━━━━━━━━━━━━━━━━━ 14s 50ms/step - accuracy: 1.0000 - loss: 1.6940 - recall: 1.0000 - val_accuracy: 0.8993 - val_loss: 1.9159 - val_recall: 0.8270 - learning_rate: 1.0000e-05
# Epoch 17/50
# 277/277 ━━━━━━━━━━━━━━━━━━━━ 14s 50ms/step - accuracy: 1.0000 - loss: 1.5384 - recall: 1.0000 - val_accuracy: 0.8979 - val_loss: 1.7765 - val_recall: 0.8228 - learning_rate: 1.0000e-05
# Epoch 18/50
# 277/277 ━━━━━━━━━━━━━━━━━━━━ 14s 49ms/step - accuracy: 1.0000 - loss: 1.3870 - recall: 1.0000 - val_accuracy: 0.8875 - val_loss: 1.6907 - val_recall: 0.8018 - learning_rate: 1.0000e-05
# Epoch 19/50
# 277/277 ━━━━━━━━━━━━━━━━━━━━ 14s 49ms/step - accuracy: 0.9996 - loss: 1.2423 - recall: 0.9995 - val_accuracy: 0.8911 - val_loss: 1.5390 - val_recall: 0.8094 - learning_rate: 1.0000e-05
# Epoch 20/50
# 277/277 ━━━━━━━━━━━━━━━━━━━━ 14s 49ms/step - accuracy: 1.0000 - loss: 1.1030 - recall: 1.0000 - val_accuracy: 0.8921 - val_loss: 1.4156 - val_recall: 0.8102 - learning_rate: 1.0000e-05
# Epoch 21/50
# 277/277 ━━━━━━━━━━━━━━━━━━━━ 14s 49ms/step - accuracy: 1.0000 - loss: 0.9714 - recall: 1.0000 - val_accuracy: 0.8830 - val_loss: 1.3373 - val_recall: 0.7918 - learning_rate: 1.0000e-05
# Epoch 21: early stopping
# Restoring model weights from the end of the best epoch: 1.
#    Epochs effectués : 21
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-4241520105.py in <cell line: 0>()
#      39 best_val_accuracy = max(history_frozen.history['val_accuracy'])
#      40 best_epoch_recall = history_frozen.history['val_recall'].index(best_val_recall) + 1
# ---> 41 best_epoch_accuracy = history_frozen.history['val_accuracy'].index(best_val_recall) + 1
#      42 print(f"   Meilleure val_recall : {best_val_recall*100:.2f}% (epoch {best_epoch_recall})")
#      43 print(f"   Meilleure val_accuracy : {best_val_accuracy*100:.2f}% (epoch {best_epoch_accuracy})")
#
# ValueError: 0.966414749622345 is not in list

# %%
print("🔍 \n")
print("="*80)

# Obtenir quelques prédictions sur le validation set
for images, labels in val_ds_prepared.take(1):
    predictions = model_frozen.predict(images[:32], verbose=0)

    print("\n📊 Échantillon de prédictions :")
    print("-"*80)

    for i in range(32):
        true_label = int(labels[i])
        pred_label = int(np.round(predictions[i]))

        status = "✅" if true_label == pred_label else "❌"
        print(f"{status} Image {i+1}: Vrai={class_names[true_label]:12s} | Prédit={class_names[pred_label]:12s}")
# Out:
# 🔍
#
# ================================================================================
#
# 📊 Échantillon de prédictions :
# --------------------------------------------------------------------------------
# ✅ Image 1: Vrai=non_violence | Prédit=non_violence
# ✅ Image 2: Vrai=violence     | Prédit=violence
# ❌ Image 3: Vrai=non_violence | Prédit=violence
# ❌ Image 4: Vrai=non_violence | Prédit=violence
# ❌ Image 5: Vrai=non_violence | Prédit=violence
# ✅ Image 6: Vrai=non_violence | Prédit=non_violence
# ✅ Image 7: Vrai=violence     | Prédit=violence
# ✅ Image 8: Vrai=non_violence | Prédit=non_violence
# ✅ Image 9: Vrai=violence     | Prédit=violence
# ✅ Image 10: Vrai=violence     | Prédit=violence
# ✅ Image 11: Vrai=non_violence | Prédit=non_violence
# ❌ Image 12: Vrai=non_violence | Prédit=violence
# ✅ Image 13: Vrai=violence     | Prédit=violence
# ❌ Image 14: Vrai=non_violence | Prédit=violence
# ✅ Image 15: Vrai=non_violence | Prédit=non_violence
# ✅ Image 16: Vrai=violence     | Prédit=violence
# ❌ Image 17: Vrai=non_violence | Prédit=violence
# ❌ Image 18: Vrai=non_violence | Prédit=violence
# ✅ Image 19: Vrai=non_violence | Prédit=non_violence
# ❌ Image 20: Vrai=non_violence | Prédit=violence
# ✅ Image 21: Vrai=violence     | Prédit=violence
# ✅ Image 22: Vrai=violence     | Prédit=violence
# ✅ Image 23: Vrai=violence     | Prédit=violence
# ✅ Image 24: Vrai=non_violence | Prédit=non_violence
# ✅ Image 25: Vrai=violence     | Prédit=violence
# ✅ Image 26: Vrai=violence     | Prédit=violence
# ✅ Image 27: Vrai=violence     | Prédit=violence
# ✅ Image 28: Vrai=non_violence | Prédit=non_violence
# ✅ Image 29: Vrai=violence     | Prédit=violence
# ✅ Image 30: Vrai=violence     | Prédit=violence
# ✅ Image 31: Vrai=violence     | Prédit=violence
# ✅ Image 32: Vrai=violence     | Prédit=violence

# %% [markdown]
# ## Diagnostic du modèle frozen

# %%
# Évaluation sur validation
print("📊 Évaluation du modèle frozen sur validation...\n")

results_frozen = model_frozen.evaluate(val_ds_prepared, verbose=0)

print("Résultats :")
print(f"  - Loss                : {results_frozen[0]:.4f}")
print(f"  - Recall            : {results_frozen[1]*100:.2f}%")

# Visualiser les courbes d'entraînement
fig, axes = plt.subplots(1, 3, figsize=(16, 5))

# Loss
axes[0].plot(history_frozen.history['loss'], label='Train Loss', linewidth=2)
axes[0].plot(history_frozen.history['val_loss'], label='Val Loss', linewidth=2)
axes[0].set_xlabel('Epoch', fontsize=12)
axes[0].set_ylabel('Loss', fontsize=12)
axes[0].set_title('Loss - Modèle Frozen', fontsize=14, fontweight='bold')
axes[0].legend(fontsize=11)
axes[0].grid(alpha=0.3)

# Accuracy
axes[1].plot(history_frozen.history['accuracy'], label='Train Accuracy', linewidth=2)
axes[1].plot(history_frozen.history['val_accuracy'], label='Val Accuracy', linewidth=2)
axes[1].set_xlabel('Epoch', fontsize=12)
axes[1].set_ylabel('Accuracy', fontsize=12)
axes[1].set_title('Accuracy - Modèle Frozen', fontsize=14, fontweight='bold')
axes[1].legend(fontsize=11)
axes[1].grid(alpha=0.3)

# Recall
axes[2].plot(history_frozen.history['recall'], label='Train Recall', linewidth=2)
axes[2].plot(history_frozen.history['val_recall'], label='Val Recall', linewidth=2)
axes[2].set_xlabel('Epoch', fontsize=12)
axes[2].set_ylabel('Recall', fontsize=12)
axes[2].set_title('Recall - Modèle Frozen', fontsize=14, fontweight='bold')
axes[2].legend(fontsize=11)
axes[2].grid(alpha=0.3)

plt.suptitle('Entraînement du modèle avec Feature Extraction (Frozen)', fontsize=16, fontweight='bold', y=1.02)
plt.tight_layout()
plt.show()

print("\n💡 Le modèle frozen donne déjà de bons résultats !")
print("   Voyons maintenant si le fine-tuning peut améliorer les performances.")
# Out:
# 📊 Évaluation du modèle frozen sur validation...
#
# Résultats :
#   - Loss                : 4.5145
#   - Recall            : 80.26%
# 💡 Le modèle frozen donne déjà de bons résultats !
#    Voyons maintenant si le fine-tuning peut améliorer les performances.

# %% [markdown]
# ## Sauvegarde du modèle

# %%
model_path = 'sample_data/mobilenetv2_flowers_finetuned.keras'
model_frozen.save(model_path)

print(f"✅ Modèle sauvegardé : {model_path}")
print(f"   Taille du fichier : {os.path.getsize(model_path) / (1024**2):.1f} MB")
# Out:
# ✅ Modèle sauvegardé : sample_data/mobilenetv2_flowers_finetuned.keras
#    Taille du fichier : 27.2 MB
