# %% [markdown]
# <a href="https://colab.research.google.com/github/francisbonheur/alyra_projet_deep_learning/blob/main/notebooks/cv-violence-detection-mobilenetv2-fine-tuning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Computer vision : détection d'images violentes (fine tuning)
#
# ## Chargement modules python

# %%
# Bibliothèques principales
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import clear_output, Image as IPImage, display
import warnings
import os
from pathlib import Path
warnings.filterwarnings('ignore')

# TensorFlow et Keras
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models, optimizers, callbacks
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.preprocessing import image_dataset_from_directory
from tensorflow.keras.utils import image_dataset_from_directory

from sklearn.metrics import confusion_matrix
import seaborn as sns

# %% [markdown]
# ## Chargement du modèle MobileNetV2 avec Keras

# %%
print("📥 Chargement du modèle MobileNetV2 avec Keras...")
print("   (Cela peut prendre quelques secondes la première fois)\n")

# Charger MobileNetV2 pré-entraîné sans le classifier (include_top=False)
base_model = MobileNetV2(
    input_shape=(224, 224, 3),
    include_top=False,  # Exclure la couche de classification ImageNet
    weights='imagenet',  # Charger les poids pré-entraînés sur ImageNet
    pooling='avg'  # Global Average Pooling à la fin
)
# Out:
# 📥 Chargement du modèle MobileNetV2 avec Keras...
#    (Cela peut prendre quelques secondes la première fois)

# %% [markdown]
# ## Chaergement du dataset

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("abdulmananraja/real-life-violence-situations")

data_dir = path + "/new_violence"

print("Path to dataset files:", data_dir)
# Out:
# Using Colab cache for faster access to the 'real-life-violence-situations' dataset.
# Path to dataset files: /kaggle/input/real-life-violence-situations/new_violence

# %% [markdown]
# ## Préparation du dataset

# %%
print("🔧 Préparation des datasets...\n")

# Paramètres
BATCH_SIZE = 32
IMG_SIZE = (224, 224)
VALIDATION_SPLIT = 0.2
SEED = 42

# Créer le dataset d'entraînement avec filtrage des classes
train_ds = tf.keras.utils.image_dataset_from_directory(
    data_dir,
    validation_split=VALIDATION_SPLIT,
    subset="training",
    seed=SEED,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    label_mode='binary',
    labels='inferred'
)

# Créer le dataset de validation avec les mêmes classes
val_ds = tf.keras.utils.image_dataset_from_directory(
    data_dir,
    validation_split=VALIDATION_SPLIT,
    subset="validation",
    seed=SEED,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    label_mode='binary',
    labels='inferred'
)

# Obtenir les noms de classes (devrait être les 5 classes de fleurs)
class_names = train_ds.class_names
num_classes = len(class_names)

print(f"✅ Datasets créés !\n")
print(f"📊 Information sur les datasets :")
print(f"  - Classes        : {class_names}")
print(f"  - Nombre de classes : {num_classes}")

print(f"\n  - Train batches  : {len(train_ds)}")
print(f"  - Val batches    : {len(val_ds)}")

print(f"  - Batch size     : {BATCH_SIZE}")
print(f"  - Image size     : {IMG_SIZE}")
print(f"\n  - Train samples  : ~{len(train_ds) * BATCH_SIZE}")
print(f"  - Val samples    : ~{len(val_ds) * BATCH_SIZE}")
# Out:
# 🔧 Préparation des datasets...
#
# Found 11073 files belonging to 2 classes.
# Using 8859 files for training.
# Found 11073 files belonging to 2 classes.
# Using 2214 files for validation.
# ✅ Datasets créés !
#
# 📊 Information sur les datasets :
#   - Classes        : ['non_violence', 'violence']
#   - Nombre de classes : 2
#
#   - Train batches  : 277
#   - Val batches    : 70
#   - Batch size     : 32
#   - Image size     : (224, 224)
#
#   - Train samples  : ~8864
#   - Val samples    : ~2240

# %% [markdown]
# ## Préprocessing (normalisation et data augmentation)

# %%
print("🎨 Configuration du prétraitement et de la data augmentation...\n")

# Créer une fonction de prétraitement pour MobileNetV2
from tensorflow.keras.applications.mobilenet_v2 import preprocess_input

# Créer un modèle d'augmentation de données plus agressif
data_augmentation = keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.3),  # Rotation jusqu'à 30%
    layers.RandomZoom(0.2),
], name="data_augmentation")

# Fonction pour appliquer le prétraitement
def prepare_dataset(ds, augment=False, shuffle=True):
    # Normalisation MobileNetV2
    normalization = lambda x, y: (preprocess_input(x), y)
    ds = ds.map(normalization, num_parallel_calls=tf.data.AUTOTUNE)

    # Augmentation (seulement pour le train)
    if augment:
        augmentation = lambda x, y: (data_augmentation(x, training=True), y)
        ds = ds.map(augmentation, num_parallel_calls=tf.data.AUTOTUNE)

    # Shuffle pour le training
    if shuffle:
        ds = ds.shuffle(1000)

    # Optimisation des performances
    ds = ds.cache()  # Cache en mémoire
    ds = ds.prefetch(buffer_size=tf.data.AUTOTUNE)  # Prefetch pour accélérer

    return ds

# Appliquer le prétraitement
train_ds_prepared = prepare_dataset(train_ds, augment=True, shuffle=True)
val_ds_prepared = prepare_dataset(val_ds, augment=False, shuffle=False)
# Out:
# 🎨 Configuration du prétraitement et de la data augmentation...

# %% [markdown]
# ##  Effet de la data augmentation

# %%
# Prendre un batch d'exemples
for images, labels in train_ds.take(1):
    # Prendre la première image
    sample_image = images[0].numpy().astype("uint8")

    # Appliquer l'augmentation 9 fois
    fig, axes = plt.subplots(2, 5, figsize=(18, 8))
    axes = axes.flatten()

    # Image originale
    axes[0].imshow(sample_image)
    axes[0].set_title('Original', fontsize=12, fontweight='bold')
    axes[0].axis('off')

    # Images augmentées
    for i in range(1, 10):
        augmented = data_augmentation(tf.expand_dims(sample_image, 0), training=True)
        axes[i].imshow(augmented[0].numpy().astype("uint8"))
        axes[i].set_title(f'Augmentation {i}', fontsize=12)
        axes[i].axis('off')

    plt.suptitle('Effet de la Data Augmentation', fontsize=16, fontweight='bold', y=0.98)
    plt.tight_layout()
    plt.show()
    break

# %% [markdown]
# ## Construction du modèle Feature Extraction

# %%
# Dégeler le base_model
base_model.trainable = True

# Geler seulement les 100 premières couches
fine_tune_at = 100

for i, layer in enumerate(base_model.layers):
    if i < fine_tune_at:
        layer.trainable = False
    else:
        layer.trainable = True


print(f"✅ Modèle de base gelé")
print(f"   {len(base_model.layers)} couches non-entraînables\n")

# Architecture OPTIMALE pour ce dataset
inputs = keras.Input(shape=(224, 224, 3))
x = base_model(inputs, training=False)

# Classifier avec régularisation modérée
x = layers.Dropout(0.3)(x)  # Dropout modéré
x = layers.Dense(256, activation='relu', kernel_regularizer=keras.regularizers.l2(0.01))(x)
x = layers.Dropout(0.3)(x)
outputs = layers.Dense(1, activation='sigmoid')(x)

model_finetuned = keras.Model(inputs, outputs, name='MobileNetV2_FineTuned')

FINE_TUNE_LR = 1e-5

# Compiler avec LR optimal
model_finetuned.compile(
    optimizer=optimizers.Adam(learning_rate=FINE_TUNE_LR),  # LR standard
    loss='binary_crossentropy',
    metrics=[tf.keras.metrics.BinaryAccuracy(name='accuracy'),
             tf.keras.metrics.Recall(name='recall'),
             tf.keras.metrics.Precision(name='precision'),
             tf.keras.metrics.FBetaScore(name='f2_score', beta=2.0, threshold=0.5)]
)

trainable = sum([tf.size(w).numpy() for w in model_finetuned.trainable_weights])
non_trainable = sum([tf.size(w).numpy() for w in model_finetuned.non_trainable_weights])

print(f"\n  - Paramètres entraînables    : {trainable:,}")
print(f"  - Paramètres non-entraînables: {non_trainable:,}")
print(f"  - Total                      : {trainable + non_trainable:,}")
# Out:
# ✅ Modèle de base gelé
#    155 couches non-entraînables
#
#
#   - Paramètres entraînables    : 2,189,633
#   - Paramètres non-entraînables: 396,544
#   - Total                      : 2,586,177

# %% [markdown]
# ## Entraînement du modèle

# %%
# Callbacks
early_stopping = callbacks.EarlyStopping(
    monitor='val_loss',
    patience=10,  # Patience raisonnable
    restore_best_weights=True,
    mode='min',
    verbose=1
)

reduce_lr = callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=4,
    min_lr=1e-7,
    verbose=1
)

checkpoint = callbacks.ModelCheckpoint(
    'best_model_finetuned.keras',
    monitor='val_f2_score',
    save_best_only=True,
    mode='max',
    verbose=0
)

EPOCHS_FINETUNE = 200

history_finetuned = model_finetuned.fit(
    train_ds_prepared,
    validation_data=val_ds_prepared,
    epochs=EPOCHS_FINETUNE,
    callbacks=[early_stopping, reduce_lr, checkpoint],
    verbose=1
)

print(f"   Epochs effectués : {len(history_finetuned.history['loss'])}")

best_val_f2_score = max(history_finetuned.history['val_f2_score'])
best_val_accuracy = max(history_finetuned.history['val_accuracy'])
best_epoch_f2_score = history_finetuned.history['val_f2_score'].index(best_val_f2_score) + 1
best_epoch_accuracy = history_finetuned.history['val_accuracy'].index(best_val_accuracy) + 1
print(f"   Meilleure val_f2_score : {best_val_f2_score*100:.2f}% (epoch {best_epoch_f2_score})")
print(f"   Meilleure val_accuracy : {best_val_accuracy*100:.2f}% (epoch {best_epoch_accuracy})")
# Out:
# Epoch 1/200
# 277/277 ━━━━━━━━━━━━━━━━━━━━ 190s 196ms/step - accuracy: 0.5959 - f2_score: 0.6789 - loss: 4.9316 - precision: 0.5996 - recall: 0.7027 - val_accuracy: 0.7958 - val_f2_score: 0.8882 - val_loss: 4.5284 - val_precision: 0.7498 - val_recall: 0.9312 - learning_rate: 1.0000e-05
# Epoch 2/200
# 277/277 ━━━━━━━━━━━━━━━━━━━━ 14s 50ms/step - accuracy: 0.7936 - f2_score: 0.8070 - loss: 4.4991 - precision: 0.7997 - recall: 0.8089 - val_accuracy: 0.8577 - val_f2_score: 0.8881 - val_loss: 4.2463 - val_precision: 0.8460 - val_recall: 0.8992 - learning_rate: 1.0000e-05
# Epoch 3/200
# 277/277 ━━━━━━━━━━━━━━━━━━━━ 14s 50ms/step - accuracy: 0.8443 - f2_score: 0.8465 - loss: 4.2215 - precision: 0.8569 - recall: 0.8440 - val_accuracy: 0.8821 - val_f2_score: 0.8787 - val_loss: 4.0212 - val_precision: 0.9051 - val_recall: 0.8724 - learning_rate: 1.0000e-05
# Epoch 4/200
# 277/277 ━━━━━━━━━━━━━━━━━━━━ 14s 50ms/step - accuracy: 0.8858 - f2_score: 0.8854 - loss: 3.9869 - precision: 0.8979 - recall: 0.8824 - val_accuracy: 0.8911 - val_f2_score: 0.8712 - val_loss: 3.8356 - val_precision: 0.9358 - val_recall: 0.8564 - learning_rate: 1.0000e-05
# Epoch 5/200
# 277/277 ━━━━━━━━━━━━━━━━━━━━ 14s 49ms/step - accuracy: 0.9068 - f2_score: 0.9080 - loss: 3.7684 - precision: 0.9152 - recall: 0.9062 - val_accuracy: 0.8979 - val_f2_score: 0.8628 - val_loss: 3.6702 - val_precision: 0.9653 - val_recall: 0.8405 - learning_rate: 1.0000e-05
# Epoch 6/200
# 277/277 ━━━━━━━━━━━━━━━━━━━━ 14s 50ms/step - accuracy: 0.9288 - f2_score: 0.9274 - loss: 3.5591 - precision: 0.9386 - recall: 0.9246 - val_accuracy: 0.8907 - val_f2_score: 0.8479 - val_loss: 3.5226 - val_precision: 0.9703 - val_recall: 0.8220 - learning_rate: 1.0000e-05
# Epoch 7/200
# 277/277 ━━━━━━━━━━━━━━━━━━━━ 14s 50ms/step - accuracy: 0.9435 - f2_score: 0.9443 - loss: 3.3540 - precision: 0.9486 - recall: 0.9433 - val_accuracy: 0.8812 - val_f2_score: 0.8281 - val_loss: 3.3906 - val_precision: 0.9774 - val_recall: 0.7976 - learning_rate: 1.0000e-05
# Epoch 8/200
# 277/277 ━━━━━━━━━━━━━━━━━━━━ 14s 50ms/step - accuracy: 0.9522 - f2_score: 0.9526 - loss: 3.1659 - precision: 0.9572 - recall: 0.9514 - val_accuracy: 0.8785 - val_f2_score: 0.8196 - val_loss: 3.2566 - val_precision: 0.9842 - val_recall: 0.7867 - learning_rate: 1.0000e-05
# Epoch 9/200
# 277/277 ━━━━━━━━━━━━━━━━━━━━ 14s 50ms/step - accuracy: 0.9705 - f2_score: 0.9717 - loss: 2.9737 - precision: 0.9721 - recall: 0.9717 - val_accuracy: 0.8681 - val_f2_score: 0.8021 - val_loss: 3.1280 - val_precision: 0.9849 - val_recall: 0.7666 - learning_rate: 1.0000e-05
# Epoch 10/200
# 277/277 ━━━━━━━━━━━━━━━━━━━━ 14s 50ms/step - accuracy: 0.9766 - f2_score: 0.9751 - loss: 2.7944 - precision: 0.9819 - recall: 0.9734 - val_accuracy: 0.8627 - val_f2_score: 0.7921 - val_loss: 3.0121 - val_precision: 0.9868 - val_recall: 0.7548 - learning_rate: 1.0000e-05
# Epoch 11/200
# 277/277 ━━━━━━━━━━━━━━━━━━━━ 14s 49ms/step - accuracy: 0.9883 - f2_score: 0.9874 - loss: 2.6144 - precision: 0.9911 - recall: 0.9865 - val_accuracy: 0.8600 - val_f2_score: 0.7864 - val_loss: 2.8793 - val_precision: 0.9889 - val_recall: 0.7481 - learning_rate: 1.0000e-05
# Epoch 12/200
# 277/277 ━━━━━━━━━━━━━━━━━━━━ 14s 49ms/step - accuracy: 0.9927 - f2_score: 0.9916 - loss: 2.4430 - precision: 0.9955 - recall: 0.9907 - val_accuracy: 0.8464 - val_f2_score: 0.7609 - val_loss: 2.7991 - val_precision: 0.9942 - val_recall: 0.7187 - learning_rate: 1.0000e-05
# Epoch 13/200
# 277/277 ━━━━━━━━━━━━━━━━━━━━ 14s 50ms/step - accuracy: 0.9945 - f2_score: 0.9930 - loss: 2.2771 - precision: 0.9976 - recall: 0.9919 - val_accuracy: 0.8618 - val_f2_score: 0.7894 - val_loss: 2.6011 - val_precision: 0.9890 - val_recall: 0.7515 - learning_rate: 1.0000e-05
# Epoch 14/200
# 277/277 ━━━━━━━━━━━━━━━━━━━━ 14s 50ms/step - accuracy: 0.9979 - f2_score: 0.9971 - loss: 2.1125 - precision: 0.9996 - recall: 0.9965 - val_accuracy: 0.8550 - val_f2_score: 0.7764 - val_loss: 2.5093 - val_precision: 0.9921 - val_recall: 0.7364 - learning_rate: 1.0000e-05
# Epoch 15/200
# 277/277 ━━━━━━━━━━━━━━━━━━━━ 14s 49ms/step - accuracy: 0.9983 - f2_score: 0.9982 - loss: 1.9533 - precision: 0.9986 - recall: 0.9981 - val_accuracy: 0.8509 - val_f2_score: 0.7696 - val_loss: 2.3756 - val_precision: 0.9920 - val_recall: 0.7288 - learning_rate: 1.0000e-05
# Epoch 16/200
# 277/277 ━━━━━━━━━━━━━━━━━━━━ 14s 50ms/step - accuracy: 0.9999 - f2_score: 0.9998 - loss: 1.7950 - precision: 1.0000 - recall: 0.9997 - val_accuracy: 0.8532 - val_f2_score: 0.7734 - val_loss: 2.2307 - val_precision: 0.9920 - val_recall: 0.7330 - learning_rate: 1.0000e-05
# Epoch 17/200
# 277/277 ━━━━━━━━━━━━━━━━━━━━ 14s 49ms/step - accuracy: 0.9993 - f2_score: 0.9993 - loss: 1.6418 - precision: 0.9995 - recall: 0.9992 - val_accuracy: 0.8523 - val_f2_score: 0.7725 - val_loss: 2.0909 - val_precision: 0.9909 - val_recall: 0.7322 - learning_rate: 1.0000e-05
# Epoch 18/200
# 277/277 ━━━━━━━━━━━━━━━━━━━━ 14s 49ms/step - accuracy: 1.0000 - f2_score: 1.0000 - loss: 1.4918 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.8582 - val_f2_score: 0.7822 - val_loss: 1.9359 - val_precision: 0.9910 - val_recall: 0.7431 - learning_rate: 1.0000e-05
# Epoch 19/200
# 277/277 ━━━━━━━━━━━━━━━━━━━━ 14s 49ms/step - accuracy: 0.9996 - f2_score: 0.9994 - loss: 1.3462 - precision: 1.0000 - recall: 0.9992 - val_accuracy: 0.8690 - val_f2_score: 0.8006 - val_loss: 1.7573 - val_precision: 0.9902 - val_recall: 0.7641 - learning_rate: 1.0000e-05
# Epoch 20/200
# 277/277 ━━━━━━━━━━━━━━━━━━━━ 14s 50ms/step - accuracy: 0.9996 - f2_score: 0.9994 - loss: 1.2065 - precision: 1.0000 - recall: 0.9992 - val_accuracy: 0.8582 - val_f2_score: 0.7822 - val_loss: 1.6557 - val_precision: 0.9910 - val_recall: 0.7431 - learning_rate: 1.0000e-05
# Epoch 21/200
# 277/277 ━━━━━━━━━━━━━━━━━━━━ 14s 49ms/step - accuracy: 1.0000 - f2_score: 1.0000 - loss: 1.0717 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.8618 - val_f2_score: 0.7882 - val_loss: 1.5307 - val_precision: 0.9911 - val_recall: 0.7498 - learning_rate: 1.0000e-05
# Epoch 22/200
# 277/277 ━━━━━━━━━━━━━━━━━━━━ 14s 49ms/step - accuracy: 0.9998 - f2_score: 0.9998 - loss: 0.9449 - precision: 0.9999 - recall: 0.9997 - val_accuracy: 0.8695 - val_f2_score: 0.8020 - val_loss: 1.3787 - val_precision: 0.9892 - val_recall: 0.7657 - learning_rate: 1.0000e-05
# Epoch 23/200
# 277/277 ━━━━━━━━━━━━━━━━━━━━ 21s 50ms/step - accuracy: 1.0000 - f2_score: 1.0000 - loss: 0.8254 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.8573 - val_f2_score: 0.7807 - val_loss: 1.3063 - val_precision: 0.9910 - val_recall: 0.7414 - learning_rate: 1.0000e-05
# Epoch 24/200
# 277/277 ━━━━━━━━━━━━━━━━━━━━ 14s 49ms/step - accuracy: 0.9996 - f2_score: 0.9994 - loss: 0.7150 - precision: 1.0000 - recall: 0.9992 - val_accuracy: 0.8672 - val_f2_score: 0.7983 - val_loss: 1.1719 - val_precision: 0.9891 - val_recall: 0.7615 - learning_rate: 1.0000e-05
# Epoch 25/200
# 277/277 ━━━━━━━━━━━━━━━━━━━━ 14s 49ms/step - accuracy: 1.0000 - f2_score: 1.0000 - loss: 0.6129 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.8586 - val_f2_score: 0.7824 - val_loss: 1.0992 - val_precision: 0.9922 - val_recall: 0.7431 - learning_rate: 1.0000e-05
# Epoch 26/200
# 277/277 ━━━━━━━━━━━━━━━━━━━━ 14s 49ms/step - accuracy: 1.0000 - f2_score: 1.0000 - loss: 0.5203 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.8659 - val_f2_score: 0.7961 - val_loss: 0.9900 - val_precision: 0.9891 - val_recall: 0.7590 - learning_rate: 1.0000e-05
# Epoch 27/200
# 277/277 ━━━━━━━━━━━━━━━━━━━━ 13s 49ms/step - accuracy: 1.0000 - f2_score: 1.0000 - loss: 0.4370 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.8645 - val_f2_score: 0.7926 - val_loss: 0.9172 - val_precision: 0.9912 - val_recall: 0.7548 - learning_rate: 1.0000e-05
# Epoch 28/200
# 277/277 ━━━━━━━━━━━━━━━━━━━━ 14s 49ms/step - accuracy: 1.0000 - f2_score: 1.0000 - loss: 0.3627 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.8640 - val_f2_score: 0.7913 - val_loss: 0.8544 - val_precision: 0.9923 - val_recall: 0.7531 - learning_rate: 1.0000e-05
# Epoch 29/200
# 277/277 ━━━━━━━━━━━━━━━━━━━━ 14s 49ms/step - accuracy: 1.0000 - f2_score: 1.0000 - loss: 0.2978 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.8740 - val_f2_score: 0.8087 - val_loss: 0.7544 - val_precision: 0.9903 - val_recall: 0.7733 - learning_rate: 1.0000e-05
# Epoch 30/200
# 277/277 ━━━━━━━━━━━━━━━━━━━━ 15s 52ms/step - accuracy: 1.0000 - f2_score: 1.0000 - loss: 0.2414 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.8708 - val_f2_score: 0.8030 - val_loss: 0.7173 - val_precision: 0.9913 - val_recall: 0.7666 - learning_rate: 1.0000e-05
# Epoch 31/200
# 277/277 ━━━━━━━━━━━━━━━━━━━━ 14s 49ms/step - accuracy: 1.0000 - f2_score: 1.0000 - loss: 0.1932 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.8695 - val_f2_score: 0.8008 - val_loss: 0.6769 - val_precision: 0.9913 - val_recall: 0.7641 - learning_rate: 1.0000e-05
# Epoch 32/200
# 277/277 ━━━━━━━━━━━━━━━━━━━━ 14s 49ms/step - accuracy: 1.0000 - f2_score: 1.0000 - loss: 0.1525 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.8735 - val_f2_score: 0.8080 - val_loss: 0.6164 - val_precision: 0.9903 - val_recall: 0.7725 - learning_rate: 1.0000e-05
# Epoch 33/200
# 277/277 ━━━━━━━━━━━━━━━━━━━━ 14s 49ms/step - accuracy: 1.0000 - f2_score: 1.0000 - loss: 0.1188 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.8808 - val_f2_score: 0.8203 - val_loss: 0.5667 - val_precision: 0.9894 - val_recall: 0.7867 - learning_rate: 1.0000e-05
# Epoch 34/200
# 277/277 ━━━━━━━━━━━━━━━━━━━━ 14s 49ms/step - accuracy: 1.0000 - f2_score: 1.0000 - loss: 0.0911 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.8785 - val_f2_score: 0.8161 - val_loss: 0.5519 - val_precision: 0.9904 - val_recall: 0.7817 - learning_rate: 1.0000e-05
# Epoch 35/200
# 277/277 ━━━━━━━━━━━━━━━━━━━━ 14s 49ms/step - accuracy: 1.0000 - f2_score: 1.0000 - loss: 0.0689 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.8808 - val_f2_score: 0.8203 - val_loss: 0.5203 - val_precision: 0.9894 - val_recall: 0.7867 - learning_rate: 1.0000e-05
# Epoch 36/200
# 277/277 ━━━━━━━━━━━━━━━━━━━━ 13s 49ms/step - accuracy: 1.0000 - f2_score: 1.0000 - loss: 0.0513 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.8753 - val_f2_score: 0.8115 - val_loss: 0.5252 - val_precision: 0.9893 - val_recall: 0.7767 - learning_rate: 1.0000e-05
# Epoch 37/200
# 277/277 ━━━━━━━━━━━━━━━━━━━━ 14s 52ms/step - accuracy: 1.0000 - f2_score: 1.0000 - loss: 0.0377 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.8753 - val_f2_score: 0.8115 - val_loss: 0.5157 - val_precision: 0.9893 - val_recall: 0.7767 - learning_rate: 1.0000e-05
# Epoch 38/200
# 277/277 ━━━━━━━━━━━━━━━━━━━━ 14s 49ms/step - accuracy: 1.0000 - f2_score: 1.0000 - loss: 0.0275 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.8753 - val_f2_score: 0.8115 - val_loss: 0.5121 - val_precision: 0.9893 - val_recall: 0.7767 - learning_rate: 1.0000e-05
# Epoch 39/200
# 277/277 ━━━━━━━━━━━━━━━━━━━━ 14s 49ms/step - accuracy: 1.0000 - f2_score: 1.0000 - loss: 0.0198 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.8853 - val_f2_score: 0.8300 - val_loss: 0.4601 - val_precision: 0.9855 - val_recall: 0.7985 - learning_rate: 1.0000e-05
# Epoch 40/200
# 277/277 ━━━━━━━━━━━━━━━━━━━━ 14s 50ms/step - accuracy: 1.0000 - f2_score: 1.0000 - loss: 0.0143 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.8826 - val_f2_score: 0.8244 - val_loss: 0.4765 - val_precision: 0.9874 - val_recall: 0.7918 - learning_rate: 1.0000e-05
# Epoch 41/200
# 277/277 ━━━━━━━━━━━━━━━━━━━━ 14s 50ms/step - accuracy: 1.0000 - f2_score: 1.0000 - loss: 0.0103 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.8839 - val_f2_score: 0.8272 - val_loss: 0.4705 - val_precision: 0.9865 - val_recall: 0.7951 - learning_rate: 1.0000e-05
# Epoch 42/200
# 277/277 ━━━━━━━━━━━━━━━━━━━━ 13s 49ms/step - accuracy: 1.0000 - f2_score: 1.0000 - loss: 0.0076 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.8844 - val_f2_score: 0.8274 - val_loss: 0.4742 - val_precision: 0.9875 - val_recall: 0.7951 - learning_rate: 1.0000e-05
# Epoch 43/200
# 276/277 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 1.0000 - f2_score: 1.0000 - loss: 0.0058 - precision: 1.0000 - recall: 1.0000
# Epoch 43: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-06.
# 277/277 ━━━━━━━━━━━━━━━━━━━━ 13s 49ms/step - accuracy: 1.0000 - f2_score: 1.0000 - loss: 0.0058 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.8826 - val_f2_score: 0.8244 - val_loss: 0.4824 - val_precision: 0.9874 - val_recall: 0.7918 - learning_rate: 1.0000e-05
# Epoch 44/200
# 277/277 ━━━━━━━━━━━━━━━━━━━━ 14s 49ms/step - accuracy: 1.0000 - f2_score: 1.0000 - loss: 0.0047 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.8866 - val_f2_score: 0.8322 - val_loss: 0.4566 - val_precision: 0.9855 - val_recall: 0.8010 - learning_rate: 5.0000e-06
# Epoch 45/200
# 277/277 ━━━━━━━━━━━━━━━━━━━━ 14s 49ms/step - accuracy: 1.0000 - f2_score: 1.0000 - loss: 0.0042 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.8862 - val_f2_score: 0.8320 - val_loss: 0.4526 - val_precision: 0.9845 - val_recall: 0.8010 - learning_rate: 5.0000e-06
# Epoch 46/200
# 277/277 ━━━━━━━━━━━━━━━━━━━━ 14s 49ms/step - accuracy: 1.0000 - f2_score: 1.0000 - loss: 0.0038 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.8884 - val_f2_score: 0.8357 - val_loss: 0.4426 - val_precision: 0.9846 - val_recall: 0.8052 - learning_rate: 5.0000e-06
# Epoch 47/200
# 277/277 ━━━━━━━━━━━━━━━━━━━━ 14s 49ms/step - accuracy: 1.0000 - f2_score: 1.0000 - loss: 0.0034 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.8889 - val_f2_score: 0.8364 - val_loss: 0.4376 - val_precision: 0.9846 - val_recall: 0.8060 - learning_rate: 5.0000e-06
# Epoch 48/200
# 277/277 ━━━━━━━━━━━━━━━━━━━━ 14s 49ms/step - accuracy: 1.0000 - f2_score: 1.0000 - loss: 0.0032 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.8907 - val_f2_score: 0.8393 - val_loss: 0.4361 - val_precision: 0.9847 - val_recall: 0.8094 - learning_rate: 5.0000e-06
# Epoch 49/200
# 277/277 ━━━━━━━━━━━━━━━━━━━━ 14s 49ms/step - accuracy: 1.0000 - f2_score: 1.0000 - loss: 0.0029 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.8907 - val_f2_score: 0.8393 - val_loss: 0.4370 - val_precision: 0.9847 - val_recall: 0.8094 - learning_rate: 5.0000e-06
# Epoch 50/200
# 277/277 ━━━━━━━━━━━━━━━━━━━━ 14s 49ms/step - accuracy: 1.0000 - f2_score: 1.0000 - loss: 0.0028 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.8930 - val_f2_score: 0.8435 - val_loss: 0.4289 - val_precision: 0.9838 - val_recall: 0.8144 - learning_rate: 5.0000e-06
# Epoch 51/200
# 277/277 ━━━━━━━━━━━━━━━━━━━━ 14s 49ms/step - accuracy: 1.0000 - f2_score: 1.0000 - loss: 0.0026 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.8898 - val_f2_score: 0.8384 - val_loss: 0.4416 - val_precision: 0.9837 - val_recall: 0.8086 - learning_rate: 5.0000e-06
# Epoch 52/200
# 277/277 ━━━━━━━━━━━━━━━━━━━━ 14s 49ms/step - accuracy: 1.0000 - f2_score: 1.0000 - loss: 0.0025 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.8939 - val_f2_score: 0.8455 - val_loss: 0.4233 - val_precision: 0.9828 - val_recall: 0.8170 - learning_rate: 5.0000e-06
# Epoch 53/200
# 277/277 ━━━━━━━━━━━━━━━━━━━━ 13s 49ms/step - accuracy: 1.0000 - f2_score: 1.0000 - loss: 0.0024 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.8939 - val_f2_score: 0.8449 - val_loss: 0.4310 - val_precision: 0.9838 - val_recall: 0.8161 - learning_rate: 5.0000e-06
# Epoch 54/200
# 277/277 ━━━━━━━━━━━━━━━━━━━━ 13s 48ms/step - accuracy: 1.0000 - f2_score: 1.0000 - loss: 0.0023 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.8875 - val_f2_score: 0.8348 - val_loss: 0.4484 - val_precision: 0.9836 - val_recall: 0.8044 - learning_rate: 5.0000e-06
# Epoch 55/200
# 277/277 ━━━━━━━━━━━━━━━━━━━━ 13s 49ms/step - accuracy: 1.0000 - f2_score: 1.0000 - loss: 0.0022 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.8875 - val_f2_score: 0.8348 - val_loss: 0.4499 - val_precision: 0.9836 - val_recall: 0.8044 - learning_rate: 5.0000e-06
# Epoch 56/200
# 276/277 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 1.0000 - f2_score: 1.0000 - loss: 0.0021 - precision: 1.0000 - recall: 1.0000
# Epoch 56: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-06.
# 277/277 ━━━━━━━━━━━━━━━━━━━━ 13s 49ms/step - accuracy: 1.0000 - f2_score: 1.0000 - loss: 0.0021 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.8911 - val_f2_score: 0.8412 - val_loss: 0.4427 - val_precision: 0.9827 - val_recall: 0.8119 - learning_rate: 5.0000e-06
# Epoch 57/200
# 277/277 ━━━━━━━━━━━━━━━━━━━━ 13s 49ms/step - accuracy: 1.0000 - f2_score: 1.0000 - loss: 0.0020 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.8902 - val_f2_score: 0.8397 - val_loss: 0.4447 - val_precision: 0.9827 - val_recall: 0.8102 - learning_rate: 2.5000e-06
# Epoch 58/200
# 277/277 ━━━━━━━━━━━━━━━━━━━━ 14s 49ms/step - accuracy: 1.0000 - f2_score: 1.0000 - loss: 0.0019 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.8875 - val_f2_score: 0.8354 - val_loss: 0.4512 - val_precision: 0.9826 - val_recall: 0.8052 - learning_rate: 2.5000e-06
# Epoch 59/200
# 277/277 ━━━━━━━━━━━━━━━━━━━━ 14s 49ms/step - accuracy: 1.0000 - f2_score: 1.0000 - loss: 0.0019 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.8898 - val_f2_score: 0.8396 - val_loss: 0.4429 - val_precision: 0.9817 - val_recall: 0.8102 - learning_rate: 2.5000e-06
# Epoch 60/200
# 276/277 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 1.0000 - f2_score: 1.0000 - loss: 0.0018 - precision: 1.0000 - recall: 1.0000
# Epoch 60: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-06.
# 277/277 ━━━━━━━━━━━━━━━━━━━━ 14s 49ms/step - accuracy: 1.0000 - f2_score: 1.0000 - loss: 0.0018 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.8884 - val_f2_score: 0.8368 - val_loss: 0.4508 - val_precision: 0.9826 - val_recall: 0.8069 - learning_rate: 2.5000e-06
# Epoch 61/200
# 277/277 ━━━━━━━━━━━━━━━━━━━━ 13s 49ms/step - accuracy: 1.0000 - f2_score: 1.0000 - loss: 0.0018 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.8889 - val_f2_score: 0.8381 - val_loss: 0.4440 - val_precision: 0.9817 - val_recall: 0.8086 - learning_rate: 1.2500e-06
# Epoch 62/200
# 277/277 ━━━━━━━━━━━━━━━━━━━━ 13s 48ms/step - accuracy: 1.0000 - f2_score: 1.0000 - loss: 0.0018 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.8889 - val_f2_score: 0.8381 - val_loss: 0.4407 - val_precision: 0.9817 - val_recall: 0.8086 - learning_rate: 1.2500e-06
# Epoch 62: early stopping
# Restoring model weights from the end of the best epoch: 52.
#    Epochs effectués : 62
#    Meilleure val_f2_score : 88.82% (epoch 1)
#    Meilleure val_accuracy : 89.79% (epoch 5)

# %%
# Obtenir quelques prédictions sur le validation set
for images, labels in val_ds_prepared.take(1):
    predictions = model_finetuned.predict(images[:32], verbose=0)

    print("\n📊 Échantillon de prédictions :")
    print("-"*80)

    for i in range(32):
        true_label = int(labels[i])
        pred_label = int(np.round(predictions[i]))

        status = "✅" if true_label == pred_label else "❌"
        print(f"{status} Image {i+1}: Vrai={class_names[true_label]:12s} | Prédit={class_names[pred_label]:12s}")
# Out:
# 📊 Échantillon de prédictions :
# --------------------------------------------------------------------------------
# ✅ Image 1: Vrai=non_violence | Prédit=non_violence
# ✅ Image 2: Vrai=violence     | Prédit=violence
# ✅ Image 3: Vrai=non_violence | Prédit=non_violence
# ❌ Image 4: Vrai=non_violence | Prédit=violence
# ✅ Image 5: Vrai=non_violence | Prédit=non_violence
# ✅ Image 6: Vrai=non_violence | Prédit=non_violence
# ✅ Image 7: Vrai=violence     | Prédit=violence
# ✅ Image 8: Vrai=non_violence | Prédit=non_violence
# ✅ Image 9: Vrai=violence     | Prédit=violence
# ✅ Image 10: Vrai=violence     | Prédit=violence
# ✅ Image 11: Vrai=non_violence | Prédit=non_violence
# ✅ Image 12: Vrai=non_violence | Prédit=non_violence
# ✅ Image 13: Vrai=violence     | Prédit=violence
# ✅ Image 14: Vrai=non_violence | Prédit=non_violence
# ✅ Image 15: Vrai=non_violence | Prédit=non_violence
# ✅ Image 16: Vrai=violence     | Prédit=violence
# ✅ Image 17: Vrai=non_violence | Prédit=non_violence
# ✅ Image 18: Vrai=non_violence | Prédit=non_violence
# ✅ Image 19: Vrai=non_violence | Prédit=non_violence
# ✅ Image 20: Vrai=non_violence | Prédit=non_violence
# ✅ Image 21: Vrai=violence     | Prédit=violence
# ❌ Image 22: Vrai=violence     | Prédit=non_violence
# ✅ Image 23: Vrai=violence     | Prédit=violence
# ✅ Image 24: Vrai=non_violence | Prédit=non_violence
# ❌ Image 25: Vrai=violence     | Prédit=non_violence
# ✅ Image 26: Vrai=violence     | Prédit=violence
# ✅ Image 27: Vrai=violence     | Prédit=violence
# ✅ Image 28: Vrai=non_violence | Prédit=non_violence
# ✅ Image 29: Vrai=violence     | Prédit=violence
# ✅ Image 30: Vrai=violence     | Prédit=violence
# ✅ Image 31: Vrai=violence     | Prédit=violence
# ✅ Image 32: Vrai=violence     | Prédit=violence

# %% [markdown]
# ## Matrice de confusion

# %%
y_labels = []
y_predictions = []
false_negative_images = []

# Display confusion matrix
for images, labels in val_ds:
    batch_size = len(labels)
    predictions = model_finetuned.predict(preprocess_input(images[:batch_size]), verbose=0)

    for i in range(batch_size):
        true_label = int(labels[i])
        pred_label = int(np.round(predictions[i]))

        y_labels.append(true_label)
        y_predictions.append(pred_label)

        if true_label == 1 and pred_label == 0:
            false_negative_images.append(images[i].numpy().astype("uint8"))


cm = confusion_matrix(y_labels,y_predictions)

plt.figure(figsize=(8, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=['Non violence', 'Violence'],
            yticklabels=['Non violence', 'Violence'])
plt.title('Matrice de Confusion')
plt.ylabel('Vraie classe')
plt.xlabel('Classe prédite')
# Out:
# Text(0.5, 58.7222222222222, 'Classe prédite')

# %% [markdown]
# ## Diagnostic du modèle frozen

# %%
# Évaluation sur validation
print("📊 Évaluation du modèle frozen sur validation...\n")

results_finetuned = model_finetuned.evaluate(val_ds_prepared, verbose=0)

print("Résultats :")
print(f"  - Loss                : {results_finetuned[0]:.4f}")
print(f"  - Accuracy            : {results_finetuned[1]*100:.2f}%")
print(f"  - F2 score            : {results_finetuned[4]*100:.2f}%")


# Visualiser les courbes d'entraînement
fig, axes = plt.subplots(1, 3, figsize=(16, 5))

# Loss
axes[0].plot(history_finetuned.history['loss'], label='Train Loss', linewidth=2)
axes[0].plot(history_finetuned.history['val_loss'], label='Val Loss', linewidth=2)
axes[0].set_xlabel('Epoch', fontsize=12)
axes[0].set_ylabel('Loss', fontsize=12)
axes[0].set_title('Loss - Modèle Frozen', fontsize=14, fontweight='bold')
axes[0].legend(fontsize=11)
axes[0].grid(alpha=0.3)

# Accuracy
axes[1].plot(history_finetuned.history['accuracy'], label='Train Accuracy', linewidth=2)
axes[1].plot(history_finetuned.history['val_accuracy'], label='Val Accuracy', linewidth=2)
axes[1].set_xlabel('Epoch', fontsize=12)
axes[1].set_ylabel('Accuracy', fontsize=12)
axes[1].set_title('Accuracy - Modèle Frozen', fontsize=14, fontweight='bold')
axes[1].legend(fontsize=11)
axes[1].grid(alpha=0.3)

# Recall
axes[2].plot(history_finetuned.history['f2_score'], label='Train F2 score', linewidth=2)
axes[2].plot(history_finetuned.history['val_f2_score'], label='Val F2 Score', linewidth=2)
axes[2].set_xlabel('Epoch', fontsize=12)
axes[2].set_ylabel('F2 score', fontsize=12)
axes[2].set_title('F2 score - Modèle Frozen', fontsize=14, fontweight='bold')
axes[2].legend(fontsize=11)
axes[2].grid(alpha=0.3)

plt.suptitle('Entraînement du modèle avec Feature Extraction (Frozen)', fontsize=16, fontweight='bold', y=1.02)
plt.tight_layout()
plt.show()

print("\n💡 Le modèle frozen donne déjà de bons résultats !")
print("   Voyons maintenant si le fine-tuning peut améliorer les performances.")
# Out:
# 📊 Évaluation du modèle frozen sur validation...
#
# Résultats :
#   - Loss                : 0.4233
#   - Accuracy            : 89.39%
#   - F2 score            : 84.55%
# 💡 Le modèle frozen donne déjà de bons résultats !
#    Voyons maintenant si le fine-tuning peut améliorer les performances.

# %% [markdown]
# ## Analyse des faux négatifs

# %%
    
fig, axes = plt.subplots(5, 5, figsize=(18, 18))
axes = axes.flatten()


for index, image in enumerate(false_negative_images):
    axes[index].imshow(image)
    axes[index].set_title(f'Faux négatif {index + 1}', fontsize=12)
    axes[index].axis('off')
    if index == 24:
        break

plt.suptitle('Exemple de faux négatifs', fontsize=16, fontweight='bold', y=0.98)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Sauvegarde du modèle

# %%
model_path = 'sample_data/mobilenetv2_flowers_fine_tuned.keras'
model_finetuned.save(model_path)

print(f"✅ Modèle sauvegardé : {model_path}")
print(f"   Taille du fichier : {os.path.getsize(model_path) / (1024**2):.1f} MB")
# Out:
# ✅ Modèle sauvegardé : sample_data/mobilenetv2_flowers_fine_tuned.keras
#    Taille du fichier : 27.2 MB
